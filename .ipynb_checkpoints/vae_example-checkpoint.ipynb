# %% [markdown]
# # Variational Autoencoder (VAE) for Image Generation and Manipulation
#
# This notebook implements a VAE to generate and manipulate simple shapes.

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# Out:
# 2024-09-30 13:26:30.537272: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-30 13:26:30.591262: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-30 13:26:30.605174: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-30 13:26:30.649518: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-30 13:26:32.182708: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Generate Simple Shapes Dataset

# %%
def generate_shapes(num_samples=1000, size=28):
    shapes = np.zeros((num_samples, size, size, 1))
    for i in range(num_samples):
        shape_type = np.random.choice(['circle', 'square', 'triangle'])
        if shape_type == 'circle':
            center = (np.random.randint(size//4, 3*size//4), np.random.randint(size//4, 3*size//4))
            radius = np.random.randint(size//8, size//4)
            y, x = np.ogrid[:size, :size]
            dist_from_center = np.sqrt((x - center[0])**2 + (y-center[1])**2)
            shapes[i, :, :, 0] = dist_from_center <= radius
        elif shape_type == 'square':
            top_left = (np.random.randint(0, size//2), np.random.randint(0, size//2))
            side = np.random.randint(size//4, size//2)
            shapes[i, top_left[0]:top_left[0]+side, top_left[1]:top_left[1]+side, 0] = 1
        else:  # triangle
            points = np.random.randint(0, size, size=(3, 2))
            x, y = np.meshgrid(range(size), range(size))
            shapes[i, :, :, 0] = (((points[1, 1] - points[0, 1]) * (x - points[0, 0]) - 
                          (points[1, 0] - points[0, 0]) * (y - points[0, 1])) >= 0) & \
                        (((points[2, 1] - points[1, 1]) * (x - points[1, 0]) - 
                          (points[2, 0] - points[1, 0]) * (y - points[1, 1])) >= 0) & \
                        (((points[0, 1] - points[2, 1]) * (x - points[2, 0]) - 
                          (points[0, 0] - points[2, 0]) * (y - points[2, 1])) >= 0)
    return shapes.astype(np.float32)

# Generate and display some sample shapes
sample_shapes = generate_shapes(5)
fig, axes = plt.subplots(1, 5, figsize=(15, 3))
for i, ax in enumerate(axes):
    ax.imshow(sample_shapes[i, :, :, 0], cmap='gray')
    ax.axis('off')
plt.show()

# %% [markdown]
# ## Define the VAE Model

# %%
class VAE(keras.Model):
    def __init__(self, latent_dim):
        super(VAE, self).__init__()
        self.latent_dim = latent_dim
        self.encoder = self.build_encoder()
        self.decoder = self.build_decoder()

    def build_encoder(self):
        encoder_inputs = keras.Input(shape=(28, 28, 1))
        x = keras.layers.Conv2D(32, 3, activation="relu", strides=2, padding="same")(encoder_inputs)
        x = keras.layers.Conv2D(64, 3, activation="relu", strides=2, padding="same")(x)
        x = keras.layers.Flatten()(x)
        x = keras.layers.Dense(16, activation="relu")(x)
        z_mean = keras.layers.Dense(self.latent_dim, name="z_mean")(x)
        z_log_var = keras.layers.Dense(self.latent_dim, name="z_log_var")(x)
        z = keras.layers.Lambda(self.sampling, output_shape=(self.latent_dim,), name="z")([z_mean, z_log_var])
        return keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")

    def build_decoder(self):
        latent_inputs = keras.Input(shape=(self.latent_dim,))
        x = keras.layers.Dense(7 * 7 * 64, activation="relu")(latent_inputs)
        x = keras.layers.Reshape((7, 7, 64))(x)
        x = keras.layers.Conv2DTranspose(64, 3, activation="relu", strides=2, padding="same")(x)
        x = keras.layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
        decoder_outputs = keras.layers.Conv2DTranspose(1, 3, activation="sigmoid", padding="same")(x)
        return keras.Model(latent_inputs, decoder_outputs, name="decoder")

    def sampling(self, args):
        z_mean, z_log_var = args
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        reconstructed = self.decoder(z)
        kl_loss = -0.5 * tf.reduce_mean(z_log_var - tf.square(z_mean) - tf.exp(z_log_var) + 1)
        self.add_loss(kl_loss)
        return reconstructed

# Create VAE model
vae = VAE(latent_dim=2)
vae.build((None, 28, 28, 1))
vae.encoder.summary()
vae.decoder.summary()
# Out:
# 2024-09-30 13:26:46.491750: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 28, 28, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 14, 14,    │        320 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 7, 7, 64)  │     18,496 │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 3136)      │          0 │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 16)        │     50,192 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mean (Dense)      │ (None, 2)         │         34 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_log_var (Dense)   │ (None, 2)         │         34 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z (Lambda)          │ (None, 2)         │          0 │ z_mean[0][0],     │
# │                     │                   │            │ z_log_var[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 69,076 (269.83 KB)
#  Trainable params: 69,076 (269.83 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3136)           │         9,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 14, 14, 64)     │        36,928 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 28, 28, 32)     │        18,464 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 28, 28, 1)      │           289 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 65,089 (254.25 KB)
#  Trainable params: 65,089 (254.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Train the VAE

# %%
def train_vae(vae, x_train, epochs, batch_size):
    vae.compile(optimizer=keras.optimizers.Adam())
    return vae.fit(x_train, x_train, epochs=epochs, batch_size=batch_size)

# Generate dataset and train VAE
x_train = generate_shapes(10000)
history = train_vae(vae, x_train, epochs=50, batch_size=128)

# Plot training loss
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()
# Out:
# Epoch 1/50
# 2024-09-30 13:26:53.041552: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 31360000 exceeds 10% of free system memory.
# 2024-09-30 13:26:53.167861: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 31360000 exceeds 10% of free system memory.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/keras/src/optimizers/base_optimizer.py:678: UserWarning: Gradients do not exist for variables ['kernel', 'bias', 'kernel', 'bias', 'kernel', 'bias', 'kernel', 'bias'] when minimizing the loss. If using `model.compile()`, did you forget to provide a `loss` argument?
#   warnings.warn(
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 6.8135e-05
# Epoch 2/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.2669e-09
# Epoch 3/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -1.5132e-09
# Epoch 4/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 7.4569e-10
# Epoch 5/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: -7.1178e-09
# Epoch 6/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -1.9871e-08
# Epoch 7/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: -6.7094e-09
# Epoch 8/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: -6.5508e-09
# Epoch 9/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: -6.5625e-09
# Epoch 10/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: -6.5634e-09
# Epoch 11/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: -6.5631e-09
# Epoch 12/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -6.5632e-09
# Epoch 13/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - loss: -6.5632e-09
# Epoch 14/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: -6.5634e-09
# Epoch 15/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: -6.5632e-09
# Epoch 16/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: -6.5633e-09
# Epoch 17/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: -6.5633e-09
# Epoch 18/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: -6.5630e-09
# Epoch 19/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -6.5633e-09
# Epoch 20/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -6.5633e-09
# Epoch 21/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: -6.5633e-09
# Epoch 22/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: -6.5633e-09
# Epoch 23/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: -6.5632e-09
# Epoch 24/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: -6.5632e-09
# Epoch 25/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: -6.5634e-09
# Epoch 26/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: -6.5634e-09
# Epoch 27/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: -6.5633e-09
# Epoch 28/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: -6.5634e-09
# Epoch 29/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: -6.5633e-09
# Epoch 30/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: -6.5634e-09
# Epoch 31/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: -6.5634e-09
# Epoch 32/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -6.5632e-09
# Epoch 33/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: -6.5633e-09
# Epoch 34/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: -6.5634e-09
# Epoch 35/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: -6.5634e-09
# Epoch 36/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -6.5633e-09
# Epoch 37/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: -6.5632e-09
# Epoch 38/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: -6.5634e-09
# Epoch 39/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: -6.5634e-09
# Epoch 40/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -6.5634e-09
# Epoch 41/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: -6.5633e-09
# Epoch 42/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: -6.5634e-09
# Epoch 43/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: -6.5633e-09
# Epoch 44/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: -6.5633e-09
# Epoch 45/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: -6.5634e-09
# Epoch 46/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: -6.5634e-09
# Epoch 47/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: -6.5634e-09
# Epoch 48/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: -6.5634e-09
# Epoch 49/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: -6.5634e-09
# Epoch 50/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: -6.5634e-09

# %% [markdown]
# ## Generate New Images

# %%
def generate_images(vae, n=10):
    z_sample = np.random.normal(size=(n, vae.latent_dim))
    x_decoded = vae.decoder.predict(z_sample)
    return x_decoded

# Generate and plot new images
generated_images = generate_images(vae, n=5)
fig, axes = plt.subplots(1, 5, figsize=(15, 3))
for i, ax in enumerate(axes):
    ax.imshow(generated_images[i, :, :, 0], cmap='gray')
    ax.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 2024-09-30 13:29:20.128117: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 20321280 exceeds 10% of free system memory.

# %% [markdown]
# ## Image Interpolation

# %%
def interpolate_images(vae, img1, img2, n_steps=10):
    z_1 = vae.encoder.predict(img1[np.newaxis, ...])[2]
    z_2 = vae.encoder.predict(img2[np.newaxis, ...])[2]
    z_interp = np.zeros((n_steps, vae.latent_dim))
    for i in range(n_steps):
        z_interp[i] = z_1 + (z_2 - z_1) * i / (n_steps - 1)
    x_interp = vae.decoder.predict(z_interp)
    return x_interp

# Interpolate between two images
img1, img2 = x_train[0], x_train[1]
interpolated_images = interpolate_images(vae, img1, img2, n_steps=10)

# Plot interpolated images
fig, axes = plt.subplots(1, 12, figsize=(24, 2))
axes[0].imshow(img1[:, :, 0], cmap='gray')
axes[0].axis('off')
axes[0].set_title('Start')
for i in range(10):
    axes[i+1].imshow(interpolated_images[i, :, :, 0], cmap='gray')
    axes[i+1].axis('off')
axes[-1].imshow(img2[:, :, 0], cmap='gray')
axes[-1].axis('off')
axes[-1].set_title('End')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 2024-09-30 13:29:25.446541: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 20321280 exceeds 10% of free system memory.

# %% [markdown]
# ## Explore Latent Space

# %%
# Generate images from a grid in latent space
n = 10
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
grid_x = np.linspace(-4, 4, n)
grid_y = np.linspace(-4, 4, n)[::-1]

for i, yi in enumerate(grid_y):
    for j, xi in enumerate(grid_x):
        z_sample = np.array([[xi, yi]])
        x_decoded = vae.decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='Greys_r')
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
